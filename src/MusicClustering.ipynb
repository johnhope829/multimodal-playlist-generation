# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
dir_path = "../data/essentia_results"
num_files = len([f for f in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, f))])
print(f"Number of files: {num_files}")
# Out:
# Number of files: 999

# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# === Configure paths ===
ESSENTIA_DIR = "../data/essentia_results"

# === PANAS-aligned emotion order
PANAS_ORDER = ["Stressed", "Angry", "Happy", "Sad", "Inspired", "Excited", "Nervous"]

# === Cluster to emotion map (7 clusters → moods)
cluster_to_emotion = {
    0: "Excited",
    1: "Inspired",
    2: "Happy",
    3: "Sad",
    4: "Happy",
    5: "Stressed",
    6: "Nervous"
}

# === Extract enhanced vibe features from JSON ===
def extract_vibe_features(essentia_json):
    low = essentia_json["lowlevel"]
    rhythm = essentia_json.get("rhythm", {})
    feats = {}

    feats["average_loudness"] = low.get("average_loudness", 0)
    feats["dynamic_complexity"] = low.get("dynamic_complexity", 0)

    for key in ["spectral_centroid", "spectral_flux", "spectral_spread", 
                "barkbands_flatness_db", "pitch_salience", "zero_crossing_rate"]:
        val = low.get(key, {})
        feats[f"{key}_mean"] = val.get("mean", 0)

    mfcc = low.get("mfcc", {}).get("mean", [0]*13)
    for i, coeff in enumerate(mfcc):
        feats[f"mfcc_{i+1}"] = coeff

    feats["bpm"] = rhythm.get("bpm", 0)
    feats["onset_rate"] = rhythm.get("onset_rate", 0)

    return feats

# === Load JSONs and extract features ===
all_features = []
track_ids = []

for fname in os.listdir(ESSENTIA_DIR):
    if fname.endswith(".json"):
        with open(os.path.join(ESSENTIA_DIR, fname), encoding="utf-8") as f:
            data = json.load(f)
        track_id = os.path.splitext(fname)[0]
        track_ids.append(track_id)
        all_features.append(extract_vibe_features(data))

df = pd.DataFrame(all_features, index=track_ids)
df.index.name = "track_id"

# === Vibe features used for clustering ===
features = [
    'average_loudness', 'spectral_centroid_mean', 'spectral_flux_mean',
    'barkbands_flatness_db_mean', 'zero_crossing_rate_mean',
    'bpm', 'onset_rate', 'dynamic_complexity'
]

# === Normalize and cluster ===
scaler = StandardScaler()
df[features] = scaler.fit_transform(df[features])
vibe_vectors = df[features].values

num_moods = 7
kmeans = KMeans(n_clusters=num_moods, random_state=42)
df['cluster'] = kmeans.fit_predict(vibe_vectors)

# === Compute mood centroids
mood_centroids = {}
for i, center in enumerate(kmeans.cluster_centers_):
    mood = cluster_to_emotion[i]
    if mood not in mood_centroids:
        mood_centroids[mood] = center

# Assign 'Angry' to same centroid as 'Stressed'
mood_centroids["Angry"] = mood_centroids["Stressed"]

# === Compute cosine similarity to all mood centroids
def get_emotion_scores(vector):
    return {
        mood: cosine_similarity(vector.reshape(1, -1), mood_centroids[mood].reshape(1, -1))[0][0]
        for mood in PANAS_ORDER
    }

# === Generate emotion score matrix
emotion_score_dicts = [get_emotion_scores(v) for v in vibe_vectors]
emotion_scores_df = pd.DataFrame(emotion_score_dicts, index=df.index)
emotion_scores_df = emotion_scores_df[PANAS_ORDER]

# === Final result: drop all else
df = emotion_scores_df.copy()

# === Optional: save
df.to_csv("../data/song_cluster_scores.csv")

# %%
df
# Out:
#                                                     Stressed     Angry  \
# track_id
# 0 - ROSÉ & Bruno Mars - APT. (Official Lyric Vi... -0.466257 -0.466257
# 10 - Bhad Bhabie - Ms. Whitman (Official Music ...  0.766747  0.766747
# 1000 - Cigarette Daydreams - Cage the Elephant     -0.298431 -0.298431
# 1001 - FloyyMenor, Cris MJ - Gata Only              0.046534  0.046534
# 1006 - Chappell Roan - Casual (Official Audio)     -0.164100 -0.164100
# ...                                                      ...       ...
# 98 - Art Deco                                       0.081216  0.081216
# 988 - Yan Block - 111 (Video Oficial)               0.115687  0.115687
# 996 - On The Floor                                 -0.066425 -0.066425
# 997 - Chappell Roan - The Giver (Official Lyric... -0.465857 -0.465857
# 999 - Chris Stapleton - Tennessee Whiskey (Offi...  0.279527  0.279527
#
#                                                        Happy       Sad  \
# track_id
# 0 - ROSÉ & Bruno Mars - APT. (Official Lyric Vi... -0.393670 -0.531235
# 10 - Bhad Bhabie - Ms. Whitman (Official Music ...  0.229367 -0.127289
# 1000 - Cigarette Daydreams - Cage the Elephant     -0.017048  0.383885
# 1001 - FloyyMenor, Cris MJ - Gata Only              0.676990  0.455744
# 1006 - Chappell Roan - Casual (Official Audio)     -0.697161  0.123541
# ...                                                      ...       ...
# 98 - Art Deco                                      -0.178258  0.566378
# 988 - Yan Block - 111 (Video Oficial)               0.307580  0.520347
# 996 - On The Floor                                 -0.147080 -0.572738
# 997 - Chappell Roan - The Giver (Official Lyric...  0.236416 -0.432094
# 999 - Chris Stapleton - Tennessee Whiskey (Offi... -0.716121  0.685093
#
#                                                     Inspired   Excited  \
# track_id
# 0 - ROSÉ & Bruno Mars - APT. (Official Lyric Vi...  0.032888  0.627270
# 10 - Bhad Bhabie - Ms. Whitman (Official Music ...  0.086282 -0.310024
# 1000 - Cigarette Daydreams - Cage the Elephant      0.002077  0.008713
# 1001 - FloyyMenor, Cris MJ - Gata Only             -0.423362 -0.833767
# 1006 - Chappell Roan - Casual (Official Audio)      0.310734  0.696057
# ...                                                      ...       ...
# 98 - Art Deco                                      -0.132151 -0.096523
# 988 - Yan Block - 111 (Video Oficial)              -0.783363 -0.673823
# 996 - On The Floor                                  0.103203  0.331052
# 997 - Chappell Roan - The Giver (Official Lyric...  0.845755  0.328187
# 999 - Chris Stapleton - Tennessee Whiskey (Offi... -0.549417  0.120614
#
#                                                      Nervous
# track_id
# 0 - ROSÉ & Bruno Mars - APT. (Official Lyric Vi... -0.360883
# 10 - Bhad Bhabie - Ms. Whitman (Official Music ...  0.591689
# 1000 - Cigarette Daydreams - Cage the Elephant     -0.507485
# 1001 - FloyyMenor, Cris MJ - Gata Only             -0.132058
# 1006 - Chappell Roan - Casual (Official Audio)     -0.150747
# ...                                                      ...
# 98 - Art Deco                                      -0.014133
# 988 - Yan Block - 111 (Video Oficial)              -0.129194
# 996 - On The Floor                                  0.203586
# 997 - Chappell Roan - The Giver (Official Lyric... -0.436741
# 999 - Chris Stapleton - Tennessee Whiskey (Offi...  0.406047
#
# [999 rows x 7 columns]

# %%
df.reset_index().to_csv('../data/music_clusters.csv', index=False)

# %%
# === Get up to 20 songs per cluster ===
sample_20_per_cluster = {}

for cluster_id in range(num_moods):
    cluster_df = df[df["cluster"] == cluster_id]
    sample_20 = cluster_df.head(20).index.tolist()
    sample_20_per_cluster[int(cluster_id)] = sample_20

# === Print ===
for cluster_id, songs in sample_20_per_cluster.items():
    print(f"\n=== Cluster {cluster_id} (Sample 20 Songs) ===")
    print(songs)
# Out:
# === Cluster 0 (Sample 20 Songs) ===
# ['1006 - Chappell Roan - Casual (Official Audio)', '1011 - The Chain (2004 Remaster)', '1023 - Come as You Are - Nirvana', '1031 - Calvin Harris - Summer (Audio)', '1034 - Last Resort', '1036 - System of a Down - Chop Suey (Remastered 2021)', '1041 - Malcolm Todd - Chest Pain (I Love) (Official Visualizer)', '1123 - ST. CHROMA', "1145 - James Arthur - Car's Outside (Official Lyric Video)", '1162 - Eagles - Hotel California (Official Audio)', "1170 - Crowded House - Don't Dream It's Over (Audio Remastered) (HQ)", '1174 - Foo Fighters - Everlong', '1210 - Todo cambió (Camila)', '1226 - Coldplay - Paradise (Official Audio)', '1248 - Camila Cabello - Shameless (Audio)', '1296 - Sabrina Carpenter - 15 Minutes (Official Lyric Video)', '1352 - NEW MAGIC WAND (Official Audio) - Tyler, The Creator', '1373 - Heavy Is the Crown (Official Audio) - Linkin Park', '1420 - Defying Gravity (Edit)', '1528 - Gorillaz - Feel Good Inc. (Official Video)']
#
# === Cluster 1 (Sample 20 Songs) ===
# ['1010 - Coldplay - Yellow', '106 - Lady Gaga, Bruno Mars - Die With A Smile (Official Music Video)', "1063 - Can't Tell Me Nothing", '1078 - Snow Patrol - Chasing Cars (Album Version)', '1105 - Clave Especial x Fuerza Regida - Como Capo [Official Video]', "1135 - Stray Kids (스트레이키즈) 'Chk Chk Boom' Official Audio", '1151 - Luke Combs - Fast Car (Lyrics)', '1167 - Calvin Harris - Feel So Close (Audio)', '1179 - The Cranberries - Linger', '1187 - The Chainsmokers & Coldplay - Something Just Like This (Audio)', '1213 - One Step Closer', '1227 - Till I Collapse', '1229 - Chuyin x Fuerza Regida x Jorsshh x Calle 24 - PIKA PIKA [Official Video]', '1257 - Calvin Harris - Blame (Audio) ft. John Newman', '1264 - Sabrina Carpenter - Taste (Official Lyric Video)', '1275 - Calvin Harris - My Way', '129 - Mark Ronson - Uptown Funk (Official Audio) ft. Bruno Mars', '13 - Fetty Wap  - Again [Audio Only]', '1309 - Sabrina Carpenter - Please Please Please (Lyric Video)', '1341 - Surf Curse - Freaks [Official Audio]']
#
# === Cluster 2 (Sample 20 Songs) ===
# ['1001 - FloyyMenor, Cris MJ - Gata Only', '1008 - TV Girl - Cigarettes out the Window (Lyrics)', '1019 - Les', '1022 - Cazzu - Con Otra Letra', '103 - Kendrick Lamar - peekaboo (Official Audio)', '1059 - Could You Be Loved (1991) - Bob Marley & The Wailers', '11 - Amor', '112 - Billie Eilish - BIRDS OF A FEATHER (Official Lyric Video)', '1143 - Elton John, Dua Lipa - Cold Heart (PNAU Remix) (Official Video)', '1144 - SZA - Broken Clocks (Official Audio)', '1146 - Shakira - Chantaje (Audio) ft. Maluma', '1152 - Tate McRae - Sports car (Lyric Video)', '1156 - Quevedo - Columbia (Letra⧸Lyrics)', '1180 - Chino Pacas - Morena Canela [Video Visualizador Oficial]', '1184 - J. Cole - Work Out (Audio)', '1220 - Cameron Whitcomb - Medusa (Official Lyric Video)', '1221 - Escápate (Lyric Video) - Tito Double P, Chino Pacas', '1231 - Bad Bunny ft. Chencho Corleone - Me Porto Bonito (Video Oficial) ｜ Un Verano Sin Ti', '1239 - Feid - Feliz Cumpleaños Ferxxo (Official Video)', '1251 - Jay Wheeler Ft Myke Towers - La Curiosidad (Official Audio)']
#
# === Cluster 3 (Sample 20 Songs) ===
# ['1000 - Cigarette Daydreams - Cage the Elephant', "1016 - Morgan Wallen - Chasin' You (Audio Only)", '1018 - Coldplay - Viva la Vida (Audio)', '1030 - Redbone', '1071 - Lana Del Rey - Cinnamon Girl', '1092 - Comfortably Numb', '1140 - Like Him', '1155 - Morgan Wallen - Just In Case (Official Audio)', '1159 - Chris Stapleton - You Should Probably Leave (Official Audio)', '1168 - Coldplay - Sparks', '1171 - Primera Cita', '1176 - One Direction - Night Changes (Audio)', '1185 - Roar - I Can’t Handle Change', '1189 - Lana Del Rey - West Coast (Official Audio)', '1190 - Red Hot Chili Peppers - Under The Bridge - Remastered', '1191 - Vacations - Telephones', '1202 - Zombie', '1204 - Cris MJ - Si No Es Contigo (con el volumen de voz correcto)', '1209 - Conan Gray - Heather (Official Lyric Video)', "1225 - Nothing's Gonna Hurt You Baby - Cigarettes After Sex"]
#
# === Cluster 4 (Sample 20 Songs) ===
# ['0 - ROSÉ & Bruno Mars - APT. (Official Lyric Video)', '1013 - ¥$, Ye, Ty Dolla $ign - CARNIVAL ft. Playboi Carti & Rich The Kid', "1066 - Can't Hold Us - Macklemore & Ryan Lewis (feat. Ray Dalton)", '1068 - One Republic - Counting Stars', '1083 - Neton Vega, Tito Double P - Chiquita (Lyric Video)', '109 - Zerb & The Chainsmokers - Addicted ft. Ink (Official Video)', '1153 - Maluma - Cosas Pendientes (Official Lyric Video)', '1166 - CHRYSTAL - THE DAYS  (NOTION REMIX)', '1177 - The Beatles - Here Comes The Sun (Remastered 2009)', '1183 - Frank Ocean - Lost (432hz)', '1192 - Metro Boomin, Future, Chris Brown - Superhero (Heroes & Villains) (Visualizer)', "1203 - Gangsta's Paradise", '121 - I Wonder', '1215 - Hozier- Take Me To Church (Audio)', '1256 - Tate McRae - Revolving door (Lyric Video)', '1267 - Teddy Swims - The Door (CYRIL Remix) [Official Lyric Video]', '1276 - Sabrina Carpenter - Nonsense (Official Audio)', '1279 - BL3SS x CamrinWatsin - Kisses ft. bbyclose', '1284 - cassö, RAYE, D-Block Europe - Prada (Lyrics)', '1286 - Feather']
#
# === Cluster 5 (Sample 20 Songs) ===
# ['10 - Bhad Bhabie - Ms. Whitman (Official Music Video)', '1103 - Lana Del Rey - Chemtrails Over The Country Club (Official Music Video)', '1614 - Patrick Watson - Je te laisserai des mots (Official French Lyric Video)', '1832 - Happier Than Ever', "1909 - Don't You Worry Child (Radio Edit)", '2176 - Kendrick Lamar - tv off (Official Audio)', '2241 - Wish You Were Here', "2397 - God's Plan", '2503 - Ariana Grande - 7 rings (Official Audio)', '271 - GIVĒON - Heartbreak Anniversary (Audio)', '2799 - Don Toliver - TORE UP [Official Audio]', '3054 - Infrunami', '3155 - Shakira - Inevitable (Audio)', '3165 - 21 Savage - Ball w⧸o You (Official Audio)', "328 - V 'Winter Ahead (with PARK HYO SHIN)' Official MV", '4215 - The Marías - No One Noticed', '555 - Charli xcx - Von dutch (official lyric video)', '658 - BAD BUNNY - DtMF (Visualizer) ｜ DeBÍ TiRAR MáS FOToS', '666 - Lost Frequencies & Tom Odell - Black Friday (Pretty Like The Sun) (Lyric Video)', '684 - Frank Ocean - White Ferrari']
#
# === Cluster 6 (Sample 20 Songs) ===
# ['1715 - Evergreen (EXTENDED) Original Audio ｜ Richy Mitch & The Coal Miners', "486 - Billie Eilish - when the party's over (Official Audio)"]
